# %% [markdown]
# # Basic (Default)

# %%
from docling.document_converter import DocumentConverter

converter = DocumentConverter()

# --------------------------------------------------------------
# Basic PDF extraction
# --------------------------------------------------------------
result = converter.convert(r"D:\Research_Study\AIHealthCare\Build_UI\med_knowledge.pdf")
# result = converter.convert(r"D:\PeterTan\Coding\other\05.pdf")

document = result.document
markdown_output = document.export_to_markdown()

print(markdown_output)

# ชื่อไฟล์ที่คุณต้องการสร้าง/เขียนทับ
file_name = "med_knowledge.txt"

# โค้ดสำหรับบันทึกสตริงลงในไฟล์
try:
    with open(file_name, "w", encoding="utf-8") as file:
        file.write(markdown_output)
    print(f"บันทึกข้อมูลสำเร็จในไฟล์: {file_name}")
except Exception as e:
    print(f"เกิดข้อผิดพลาดในการบันทึก: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from docling.document_converter import DocumentConverter
#       2
#       3 converter = DocumentConverter()
#       4
#
# ModuleNotFoundError: No module named 'docling'

# %% [markdown]
# # จับคู่ตาราง (ห่วยกว่า)

# %%
# จุดที่แตกต่าง (ตารางที่ 5.3)	output_1.txt (มีข้อความติดกัน)	output_2.txt (มีการเว้นวรรค/จัดรูปแบบต่างกัน)
# ตารางที่ 5.3 บรรทัดที่ 2	กุ้งกุลาดำ | ปลาป่น | 61	กุ้งกุลาดำ | ปลาป่น กากถั่วเหลือง | 61 93
# ตารางที่ 5.3 บรรทัดที่ 3	กุ้งกุลาดำ | กากถั่วเหลือง | 93	(ไม่มีรายการนี้)

# %%
from docling.datamodel.base_models import InputFormat
from docling.document_converter import PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions


pipeline_options = PdfPipelineOptions(do_table_structure=True)
# เพื่อบังคับให้ Docling เชื่อโครงสร้างที่โมเดลทายผลมามากกว่าโครงสร้าง PDF ดั้งเดิม
pipeline_options.table_structure_options.do_cell_matching = False  # uses text cells predicted from table structure model

doc_converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

result = doc_converter.convert(r"D:\PeterTan\Coding\other\05.pdf")

document = result.document
markdown_output = document.export_to_markdown()

print(markdown_output)

# ชื่อไฟล์ที่คุณต้องการสร้าง/เขียนทับ
file_name = "output_2.txt"

# โค้ดสำหรับบันทึกสตริงลงในไฟล์
try:
    with open(file_name, "w", encoding="utf-8") as file:
        file.write(markdown_output)
    print(f"บันทึกข้อมูลสำเร็จในไฟล์: {file_name}")
except Exception as e:
    print(f"เกิดข้อผิดพลาดในการบันทึก: {e}")
# Out:
# 2025-10-07 17:49:55,715 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-07 17:49:55,733 - INFO - Going to convert document batch...
# 2025-10-07 17:49:55,734 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 2934e0be0e6f3389c8db829503ef0388
# 2025-10-07 17:49:55,734 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 17:49:58,176 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 17:49:59,715 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 17:50:00,489 - INFO - Processing document 05.pdf
# 2025-10-07 17:50:34,430 - INFO - Finished converting document 05.pdf in 38.72 sec.
# ## บทที่ 5 การสร้างสูตรอาหารสัตว์น้ำ
#
# ...

# %% [markdown]
# # Image Description (Feature)

# %% [markdown]
# ### ทดสอบกับ PDF

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat

pipeline_options = PdfPipelineOptions()
pipeline_options.do_picture_description = True

converter = DocumentConverter(format_options={
    InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
})

result = converter.convert(r"D:\PeterTan\Coding\other\05.pdf")

document = result.document
markdown_output = document.export_to_markdown()

print(markdown_output)

# ชื่อไฟล์ที่คุณต้องการสร้าง/เขียนทับ
file_name = "output_3.txt"

# โค้ดสำหรับบันทึกสตริงลงในไฟล์
try:
    with open(file_name, "w", encoding="utf-8") as file:
        file.write(markdown_output)
    print(f"บันทึกข้อมูลสำเร็จในไฟล์: {file_name}")
except Exception as e:
    print(f"เกิดข้อผิดพลาดในการบันทึก: {e}")

# %% [markdown]
# ### ทดสอบกับรูปภาพ

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat

pipeline_options = PdfPipelineOptions()
pipeline_options.do_picture_description = True

converter = DocumentConverter(format_options={
    InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
})

result = converter.convert(r"D:\PeterTan\Coding\other\extracted_images\image_325.png")

document = result.document
markdown_output = document.export_to_markdown()

print(markdown_output)
# Out:
# 2025-10-07 18:09:42,245 - INFO - detected formats: [<InputFormat.IMAGE: 'image'>]
# 2025-10-07 18:09:42,250 - INFO - Going to convert document batch...
# 2025-10-07 18:09:42,251 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-10-07 18:09:42,252 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 18:09:44,752 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 18:09:46,352 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 18:09:47,180 - INFO - Processing document image_325.png
# 2025-10-07 18:09:48,179 - INFO - Finished converting document image_325.png in 5.92 sec.
# Is Text:
#
# ## Text Value:
#
# <!-- image -->
#
# Yes
#
# <!-- image -->

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat

pipeline_options = PdfPipelineOptions()
pipeline_options.do_picture_description = True

converter = DocumentConverter(format_options={
    InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
})

result = converter.convert(r"D:\PeterTan\Coding\other\05.pdf")

document = result.document
markdown_output = document.export_to_markdown()

print(markdown_output)

# ชื่อไฟล์ที่คุณต้องการสร้าง/เขียนทับ
file_name = "output_3.txt"

# โค้ดสำหรับบันทึกสตริงลงในไฟล์
try:
    with open(file_name, "w", encoding="utf-8") as file:
        file.write(markdown_output)
    print(f"บันทึกข้อมูลสำเร็จในไฟล์: {file_name}")
except Exception as e:
    print(f"เกิดข้อผิดพลาดในการบันทึก: {e}")
# Out:
# 2025-10-07 18:00:14,881 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-07 18:00:16,127 - INFO - Going to convert document batch...
# 2025-10-07 18:00:16,129 - INFO - Initializing pipeline for StandardPdfPipeline with options hash bf0aba1c366a38f007ad7e7cbab835b8
# 2025-10-07 18:00:16,382 - INFO - Loading plugin 'docling_defaults'
# 2025-10-07 18:00:16,404 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-10-07 18:02:26,576 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 18:02:37,225 - INFO - Loading plugin 'docling_defaults'
# 2025-10-07 18:02:37,298 - INFO - Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-10-07 18:02:38,782 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 18:02:41,535 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 18:02:43,559 - INFO - Accelerator device: 'cuda:0'
# 2025-10-07 18:02:44,545 - INFO - Processing document 05.pdf
# ...

# %% [markdown]
# # โหลดไฟล์

# %%
def read_markdown_file(file_path):
    """
    อ่านเนื้อหาทั้งหมดจากไฟล์ Markdown ที่กำหนด

    Args:
        file_path (str): เส้นทางไปยังไฟล์ Markdown

    Returns:
        str: เนื้อหาของไฟล์เป็นข้อความ, หรือ None ถ้าเกิดข้อผิดพลาด
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
            return content
    except FileNotFoundError:
        print(f"Error: The file at {file_path} was not found.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# ตัวอย่างการใช้งาน
file_name = r'D:\PeterTan\Coding\sample.md'

# สมมติว่ามีไฟล์ชื่อ sample_document.md อยู่ใน directory เดียวกัน
# สร้างไฟล์ sample_document.md เพื่อทดสอบ:
# with open(file_name, 'w', encoding='utf-8') as f:
#     f.write("# Hello, World!\n\nThis is a sample markdown file.")

markdown_content = read_markdown_file(file_name)
